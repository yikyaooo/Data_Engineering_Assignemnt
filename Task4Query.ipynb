# %%
from classes.PyMongoUtils import PyMongoUtils
from classes.NewsQuery import NewsQuery
from datetime import datetime

# %%
uri = "mongodb+srv://yeohyy:9292004@cluster0.rhrp0.mongodb.net/?appName=Cluster0"
uri2 = "mongodb://yeohyy:9292004@cluster0-shard-00-00.rhrp0.mongodb.net:27017,cluster0-shard-00-01.rhrp0.mongodb.net:27017,cluster0-shard-00-02.rhrp0.mongodb.net:27017/?replicaSet=atlas-iqtkyh-shard-0&ssl=true&authSource=admin&retryWrites=true&w=majority&appName=Cluster0"
mongo = PyMongoUtils(uri2)
mongo.ping()
# Out:
# Pinged your deployment. Successfully connected to MongoDB!

# %%
collection = mongo.get_collection("News", "AnalysedResult")

# %%
nq = NewsQuery(collection)

# %% [markdown]
# # Query

# %% [markdown]
# ### Count how many articles have a positive label and mention [location] in either the title or summary (case insensitive)

# %%
nq.count_location_positive("kuala lumpur")
# Out:
# 32

# %% [markdown]
# ### Find top n most recent articles where location is set and predicted_label is either negative or neutral

# %%
nq.get_recent_by_location_and_label(3)
# Out:
# [{'_id': ObjectId('67f7ebceb2d3f5bfad017f51'),
#   'title': 'Family of seven stranded at Lata Batu Hampar falls due to water surge',
#   'summary': 'ipoh a family of seven were trapped at the lata batu hampar waterfall in kuala kangsar due to a headwater surge',
#   'publish_time': '2025-03-31 20:44:00',
#   'section': 'News',
#   'sub_section': 'Nation',
#   'keywords': [],
#   'location': 'IPOH',
#   'predicted_label': 'negative'},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9c'),
#   'title': 'Myanmar quake: SMART focuses on rescuing victims in places of worship',
#   'summary': 'kuala lumpur the special malaysia disaster assistance and rescue team smart is focusing its efforts on locating victims trapped in places of worship affected by the earthquake disaster in myanmars sagaing district',
#   'publish_time': '2025-03-31 19:59:00',
#   'section': 'News',
#   'sub_section': 'Nation',
#   'keywords': [],
#   'location': 'KUALA LUMPUR',
#   'predicted_label': 'negative'},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ece'),
#   'title': 'Missing autistic boy found dead in river 500m from Kupang home',
#   'summary': 'baling a sombre atmosphere enveloped the home of the family of mohamad fayyad affan mohd fakhri a yearold child with autism after his body was discovered on the afternoon of march  sinar harian reports',
#   'publish_time': '2025-03-31 19:24:00',
#   'section': 'News',
#   'sub_section': 'Nation',
#   'keywords': [],
#   'location': 'BALING',
#   'predicted_label': 'negative'}]

# %% [markdown]
# ### Aggregate number of articles grouped by sub_section and count how many have empty keywords

# %%
nq.count_empty_keywords_by_sub_section()
# Out:
# [{'_id': 'Nation', 'empty_keywords_count': 190},
#  {'_id': 'Aseanplus News', 'empty_keywords_count': 7},
#  {'_id': 'World', 'empty_keywords_count': 2},
#  {'_id': 'Business News', 'empty_keywords_count': 1}]

# %% [markdown]
# ### Find the average number of articles per day in given date range

# %%
start_date = datetime(2025, 3, 1)
end_date = datetime(2025, 4, 1)

# %%
nq.average_articles_per_day(start_date, end_date)
# Out:
# [{'_id': None, 'average_articles_per_day': 10.0}]

# %% [markdown]
# ### Group articles by predicted_label and find the latest article title and total count per label

# %%
nq.group_by_label_latest()
# Out:
# [{'_id': 'positive', 'count': 90, 'latest_article': '2025-03-31 19:11:00'},
#  {'_id': 'negative', 'count': 70, 'latest_article': '2025-03-31 20:44:00'},
#  {'_id': 'neutral', 'count': 40, 'latest_article': '2025-03-31 16:59:00'}]

# %% [markdown]
# ###  Top n locations with the most articles having a positive sentiment

# %%
nq.top_locations_with_positive(3)
# Out:
# [{'_id': 'KUALA LUMPUR', 'count': 33},
#  {'_id': 'PETALING JAYA', 'count': 12},
#  {'_id': 'Location not found', 'count': 6}]

# %% [markdown]
# ### Retrieve articles where title or summary contains both "communist" and "ideo" (like a stem), and ensure case-insensitive match

# %%
keywords = ["communist", "ideo"]

# %%
nq.search_articles_with_keywords(keywords)
# Out:
# [{'_id': ObjectId('67f7ebceb2d3f5bfad017e98'),
#   'title': 'Cops probing video, organisation suspected of promoting communist ideology, says IGP',
#   'summary': 'kuala lumpur police are investigating a viral video clip depicting an unregistered organisation allegedly promoting communist ideologies in the country says tan sri razarudin husain',
#   'publish_time': '2025-03-26 23:20:00',
#   'section': 'News',
#   'sub_section': 'Nation',
#   'keywords': [],
#   'location': 'KUALA LUMPUR',
#   'predicted_label': 'positive'}]

# %% [markdown]
# # Report

# %% [markdown]
# ### Monthly Sentiment Distribution Report

# %%
nq. monthly_sentiment_distribution()
# Out:
# [{'_id': {'year': 2025, 'month': 3, 'sentiment': 'positive'}, 'count': 90},
#  {'_id': {'year': 2025, 'month': 3, 'sentiment': 'negative'}, 'count': 70},
#  {'_id': {'year': 2025, 'month': 3, 'sentiment': 'neutral'}, 'count': 40}]

# %% [markdown]
# ### Location-wise Article Activity Heatmap

# %%
nq.location_sentiment_heatmap()
# Out:
# [{'_id': 'KUALA LUMPUR',
#   'total': 62,
#   'sentiments': [{'label': 'negative', 'count': 20},
#    {'label': 'positive', 'count': 33},
#    {'label': 'neutral', 'count': 9}]},
#  {'_id': 'PETALING JAYA',
#   'total': 18,
#   'sentiments': [{'label': 'negative', 'count': 2},
#    {'label': 'neutral', 'count': 4},
#    {'label': 'positive', 'count': 12}]},
#  {'_id': 'KOTA KINABALU',
#   'total': 12,
#   'sentiments': [{'label': 'positive', 'count': 4},
#    {'label': 'negative', 'count': 6},
#    {'label': 'neutral', 'count': 2}]},
#  {'_id': 'Location not found',
#   'total': 10,
#   'sentiments': [{'label': 'negative', 'count': 3},
#    {'label': 'positive', 'count': 6},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'IPOH',
#   'total': 8,
#   'sentiments': [{'label': 'negative', 'count': 3},
#    {'label': 'neutral', 'count': 5}]},
#  {'_id': 'JOHOR BARU',
#   'total': 8,
#   'sentiments': [{'label': 'negative', 'count': 2},
#    {'label': 'positive', 'count': 3},
#    {'label': 'neutral', 'count': 3}]},
#  {'_id': 'SHAH ALAM',
#   'total': 7,
#   'sentiments': [{'label': 'negative', 'count': 3},
#    {'label': 'positive', 'count': 4}]},
#  {'_id': 'MELAKA',
#   'total': 6,
#   'sentiments': [{'label': 'neutral', 'count': 1},
#    {'label': 'positive', 'count': 3},
#    {'label': 'negative', 'count': 2}]},
#  {'_id': 'PUTRAJAYA',
#   'total': 5,
#   'sentiments': [{'label': 'neutral', 'count': 1},
#    {'label': 'negative', 'count': 3},
#    {'label': 'positive', 'count': 1}]},
#  {'_id': 'KLANG',
#   'total': 4,
#   'sentiments': [{'label': 'negative', 'count': 3},
#    {'label': 'positive', 'count': 1}]},
#  {'_id': 'KOTA BHARU',
#   'total': 4,
#   'sentiments': [{'label': 'negative', 'count': 3},
#    {'label': 'positive', 'count': 1}]},
#  {'_id': 'KUALA TERENGGANU',
#   'total': 4,
#   'sentiments': [{'label': 'neutral', 'count': 1},
#    {'label': 'positive', 'count': 2},
#    {'label': 'negative', 'count': 1}]},
#  {'_id': 'GEORGE TOWN',
#   'total': 4,
#   'sentiments': [{'label': 'negative', 'count': 4}]},
#  {'_id': 'SEREMBAN',
#   'total': 3,
#   'sentiments': [{'label': 'positive', 'count': 2},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'KOTA BARU',
#   'total': 3,
#   'sentiments': [{'label': 'positive', 'count': 3}]},
#  {'_id': 'KUALA KANGSAR',
#   'total': 2,
#   'sentiments': [{'label': 'negative', 'count': 1},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'KUCHING',
#   'total': 2,
#   'sentiments': [{'label': 'neutral', 'count': 1},
#    {'label': 'negative', 'count': 1}]},
#  {'_id': 'SIBU',
#   'total': 2,
#   'sentiments': [{'label': 'negative', 'count': 1},
#    {'label': 'positive', 'count': 1}]},
#  {'_id': 'CAMERON HIGHLANDS',
#   'total': 2,
#   'sentiments': [{'label': 'positive', 'count': 1},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'TAWAU',
#   'total': 2,
#   'sentiments': [{'label': 'negative', 'count': 2}]},
#  {'_id': 'KUANTAN',
#   'total': 2,
#   'sentiments': [{'label': 'negative', 'count': 1},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'ALOR GAJAH',
#   'total': 2,
#   'sentiments': [{'label': 'neutral', 'count': 1},
#    {'label': 'positive', 'count': 1}]},
#  {'_id': 'NIBONG TEBAL',
#   'total': 2,
#   'sentiments': [{'label': 'positive', 'count': 2}]},
#  {'_id': 'SEPANG',
#   'total': 2,
#   'sentiments': [{'label': 'negative', 'count': 2}]},
#  {'_id': 'TAMPIN',
#   'total': 2,
#   'sentiments': [{'label': 'positive', 'count': 1},
#    {'label': 'neutral', 'count': 1}]},
#  {'_id': 'MUKAH',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'PUCHONG',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'KAJANG',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'ARAU',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'TUMPAT',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'KUALA LIPIS',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'SUNGAI PETANI',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'LABUAN',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'BAGAN SERAI',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'BUKIT MERTAJAM',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'SIK', 'total': 1, 'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'SUNGAI BULOH',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'KOTA BELUD',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'CHUKAI',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'JAKARTA',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'BALIK PULAU',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'GUA MUSANG',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'KOTA TINGGI',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'BALING',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]},
#  {'_id': 'TAPAH',
#   'total': 1,
#   'sentiments': [{'label': 'neutral', 'count': 1}]},
#  {'_id': 'SERDANG',
#   'total': 1,
#   'sentiments': [{'label': 'positive', 'count': 1}]},
#  {'_id': 'PEKAN',
#   'total': 1,
#   'sentiments': [{'label': 'negative', 'count': 1}]}]

# %% [markdown]
# ### Peak Publishing Hours Report

# %%
nq.publishing_peak_hours()
# Out:
# [{'_id': 16, 'count': 3},
#  {'_id': 17, 'count': 1},
#  {'_id': 18, 'count': 2},
#  {'_id': 19, 'count': 14},
#  {'_id': 20, 'count': 37},
#  {'_id': 21, 'count': 60},
#  {'_id': 22, 'count': 51},
#  {'_id': 23, 'count': 32}]

# %% [markdown]
# ###  Articles with Potential Low Content Quality

# %%
nq.low_content_quality_articles()
# Out:
# [{'_id': ObjectId('67f7ebceb2d3f5bfad017ec4'),
#   'title': "Labourer who attempted to evade arrest gets eight month's jail, RM6,000 fine",
#   'summary': 'labourer who attempted to evade arrest gets eight months jail rm fine',
#   'summary_length': 69,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ead'),
#   'title': 'Over 1,000 attend Iftar event with PM in Tampin',
#   'summary': 'tampin more than  attendees enlivened the iftar event with prime minister datuk seri anwar ibrahim',
#   'summary_length': 98,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f24'),
#   'title': 'Melaka named official venue for Visit Malaysia Year 2026 launch',
#   'summary': 'melaka historic city is designated as the official venue for the launch of visit malaysia year  vmy',
#   'summary_length': 99,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f44'),
#   'title': 'Two men slashed to death in a fight at Taman Sentosa',
#   'summary': 'klang two men were killed after being slashed during a fight at a business premises in taman sentosa',
#   'summary_length': 100,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9e'),
#   'title': 'Flood situation worsens in Sarawak, improves in Sabah as evacuee numbers shift',
#   'summary': 'petaling jaya the flood situation in sarawak has worsened with the number of evacuees rising steadily',
#   'summary_length': 101,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f3d'),
#   'title': 'Car carrying firecrackers catches fire at busy intersection in Lumut',
#   'summary': 'ipoh a car carrying firecrackers in its trunk caught fire at a busy intersection in bukit permata lumut',
#   'summary_length': 103,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eae'),
#   'title': 'Woman dies after falling from Shah Alam i-City bridge',
#   'summary': 'klang a woman believed to have fallen off a bridge died on the spot near here on saturday evening march ',
#   'summary_length': 104,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f51'),
#   'title': 'Family of seven stranded at Lata Batu Hampar falls due to water surge',
#   'summary': 'ipoh a family of seven were trapped at the lata batu hampar waterfall in kuala kangsar due to a headwater surge',
#   'summary_length': 111,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f07'),
#   'title': "Enhance unity, harmony to safeguard Malaysia's unique diversity, urges Tiong",
#   'summary': 'kuala lumpur safeguard malaysias unique diversity by enhancing unity and harmony urges datuk seri tiong king sing',
#   'summary_length': 113,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f58'),
#   'title': 'Al-Sultan Abdullah calls for health awareness during Ramadan',
#   'summary': 'cameron highlands he said that health was a crown on the heads of the healthy visible only to those who were unwell',
#   'summary_length': 115,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f2a'),
#   'title': 'Korea Society organises buka puasa event in collaboration with Segambut parliamentary constituency',
#   'summary': 'kuala lumpur about  guests attended the  buka puasa event organised by the korean society in malaysia on sunday march ',
#   'summary_length': 118,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eaa'),
#   'title': 'Dewan Negara sitting concludes after 12 days, with 10 Bills passed',
#   'summary': 'kuala lumpur the dewan negara sitting which started on march  has concluded after  days during which  bills were passed',
#   'summary_length': 119,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eee'),
#   'title': 'Thousands throng Perak Hari Raya open house at Stadium Indera Mulia',
#   'summary': 'ipoh about  people attended the statelevel hari raya aidilfitri open house at stadium indera mulia here on monday march ',
#   'summary_length': 120,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb3'),
#   'title': 'Two young siblings feared drowned in Mukah river',
#   'summary': 'mukah two siblings are feared to have drowned while bathing in batang mukah near jalan kampung bedanga on tuesday march ',
#   'summary_length': 120,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eed'),
#   'title': 'Over 5,000 evacuated as flooding impacts Johor',
#   'summary': 'johor baru more than  people have been evacuated from their homes and placed at temporary relief centres pps across johor',
#   'summary_length': 121,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9a'),
#   'title': 'Woman claims male driver slapped her in Labuan traffic dispute',
#   'summary': 'kota kinabalu labuan police are investigating an alleged road rage incident where a woman was slapped over a traffic dispute',
#   'summary_length': 124,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb2'),
#   'title': 'Unity Department aims for 0.7 in National Unity Index this year',
#   'summary': 'tumpat the national unity and integration department is confident that the national unity index ipnas value can reach  this year',
#   'summary_length': 128,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f3e'),
#   'title': "Melaka's trishaw riders enjoy boosted earnings thanks to digital transformation",
#   'summary': 'melaka over  of the historic citys vibrant trishaw riders are now earning between rm and rm per month said melakas chief minister',
#   'summary_length': 129,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f18'),
#   'title': 'Queen extends aid to tithe recipients, single mothers',
#   'summary': 'johor baru her majesty raja zarith sofiah queen of malaysia extended donations to  recipients comprising asnaf and single mothers',
#   'summary_length': 129,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec1'),
#   'title': 'Director of Sabah State Courts Marutin Pagan dies in car accident',
#   'summary': 'sibu director of sabah state courts marutin pagan perished in an accident involving two cars on jalan kjd kanowit on sunday march ',
#   'summary_length': 130,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f3f'),
#   'title': 'Aidilfitri: 12 accident hotspots on PLUS, LPT',
#   'summary': 'kuching teams would be stationed at all the locations from march  to april  in conjunction with the upcoming aidilfitri celebration',
#   'summary_length': 131,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017efb'),
#   'title': 'Husband and wife killed in tragic accident near Sik',
#   'summary': 'sik a husband and wife have died in a tragic accident between a car and a lorry on jalan teloi timurkampung merbau kudung near here',
#   'summary_length': 131,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f43'),
#   'title': 'Sandakan police ramping up patrols over festive period',
#   'summary': 'kota kinabalu sandakan police have stepped up patrols and are deploying over  personnel to ensure peace and security in the district',
#   'summary_length': 132,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef8'),
#   'title': 'Man killed in collision with motorbike ridden by 12-year-old',
#   'summary': 'johor baru a man has been killed after the motorcycle he was on collided with another ridden by a yearold boy in kampung sri aman here',
#   'summary_length': 134,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea2'),
#   'title': 'Myanmar quake: Malaysian embassy in Bangkok temporarily closed for safety check',
#   'summary': 'petaling jaya the embassy of malaysia in bangkok located at kronos office tower has been temporarily sealed pending a safety assessment',
#   'summary_length': 135,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f27'),
#   'title': 'Selangor Ruler reminds Muslims to be wary of deviant, confusing teachings',
#   'summary': 'klang selangor ruler sultan sharafuddin idris shah reminds muslims in the state to be wary of deviant or confusing new islamic teachings',
#   'summary_length': 136,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f11'),
#   'title': 'Sultan Nazrin graces Perak-level Nuzul Al-Quran celebration',
#   'summary': 'ipoh perak ruler sultan nazrin shah attended the h statellevel nuzul alquran celebration at the sultan azlan shah mosque here monday march ',
#   'summary_length': 139,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee7'),
#   'title': 'Teen drowns at Mondikot Camp Bear, Papar',
#   'summary': 'kota kinabalu a teenage boy drowned while swimming at mondikot camp bear in kampung kaiduan papar on sunday march  while two others survived',
#   'summary_length': 140,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f4b'),
#   'title': 'Community leaders must help explain gov’t policies, achievements, says Anwar',
#   'summary': 'shah alam he also urged them not to entertain negative perceptions spread by certain parties including the opposition against the government',
#   'summary_length': 140,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f02'),
#   'title': '52-year-old woman loses over RM30,000 in investment scam',
#   'summary': 'kota tinggi a yearold woman has fallen victim to an investment scam on telegram losing rm after being lured by promises of lucrative returns',
#   'summary_length': 140,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f33'),
#   'title': "PKR veep race reflects party's strong democratic process, says Ramanan",
#   'summary': 'petaling jaya datuk seri r ramanan says the bid by seven leaders including himself for the vicepresident post reflects pkrs strong democracy',
#   'summary_length': 140,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f37'),
#   'title': "TNB activates technical, disaster squads ahead of potential K'tan floods",
#   'summary': 'petaling jaya tenaga nasional bhd tnb has activated its technical and disaster preparedness squads ahead of potential floods hitting kelantan',
#   'summary_length': 141,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec6'),
#   'title': "Miri ragging probe: Mother recalls son's military passion after tragic death",
#   'summary': 'puchong the mother of private muhammad muqriz aseri who died on monday march  described her son as deeply passionate about his military career',
#   'summary_length': 142,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f52'),
#   'title': "'Stay safe on the roads,' says Melaka top cop",
#   'summary': 'melaka melakas top cop is extending hari raya wishes to all and urges both revellers and motorists to stay safe as the festive season approaches',
#   'summary_length': 144,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec9'),
#   'title': 'Gun-wielding masked robber hits jewellery store in Damansara mall',
#   'summary': 'kuala lumpur a masked robber has pulled off a heist at gunpoint at a jewellery store located in a mall in kota damansara petaling jaya near here',
#   'summary_length': 144,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f04'),
#   'title': 'Stateless man sues for right to be granted Malaysian citizenship',
#   'summary': 'petaling jaya a stateless man who says he was born to a malaysian mother in an estate in perak is asking the government to grant him citizenship',
#   'summary_length': 144,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef5'),
#   'title': 'Negri Sembilan seeks federal support to hurry projects to prevent water crisis',
#   'summary': 'tampin negri sembilan has sought federal support to expedite the implementation of the linggi offriver storage facility ors and sabo dam projects',
#   'summary_length': 145,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f46'),
#   'title': 'Seven caught using Ramadan Bazaar stall in Penang as drug den',
#   'summary': 'george town police arrested seven men suspected of using ramadan bazaar stalls as their drug den during two raids in bayan baru on tuesday march ',
#   'summary_length': 145,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb8'),
#   'title': 'Terengganu declares March 30 as occasional holiday',
#   'summary': 'kuala terengganu the terengganu government has announced that sunday march  will be an occasional holiday in conjunction with hari raya aidilfitri',
#   'summary_length': 146,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017edf'),
#   'title': 'Floods: Number of evacuees continue to drop in Johor',
#   'summary': 'johor baru the number of flood victims in johor has continued to decline to  down from  earlier in the morning across five floodaffected districts',
#   'summary_length': 146,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee9'),
#   'title': 'Harmony in diversity: Multiracial families unite for Hari Raya festivities',
#   'summary': 'petaling jaya with hari raya aidilfitri celebrations well underway multiracial families are also joining in the festive mood with their loved ones',
#   'summary_length': 146,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec7'),
#   'title': 'Fahmi to contest PKR vice-president post',
#   'summary': 'kuala lumpur pkr information chief datuk fahmi fadzil has announced his candidacy for the partys vice president post in the party elections in may',
#   'summary_length': 146,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f17'),
#   'title': 'Third batch of 24 Malaysians rescued from Myanmar to be repatriated on Tuesday (March 25)',
#   'summary': 'the third batch of malaysian job scam victims rescued from myanmar consisting of  individuals is expected to be repatriated home on tuesday march ',
#   'summary_length': 146,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f0b'),
#   'title': 'Hari Raya: Selangor cops to deploy over 700 personnel members to ensure smooth traffic flow',
#   'summary': 'kajang selangor police will deploy  personnel members including  officers to ensure smooth traffic flow during the hari raya aidilfitri celebration',
#   'summary_length': 147,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f26'),
#   'title': 'Tourism agency advisor arrested for assaulting teenager over misunderstanding',
#   'summary': 'kuala lumpur a tourism agency advisor has been arrested for assaulting a secondary school student in saujana impian kajang near here friday afternoon',
#   'summary_length': 149,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f2f'),
#   'title': 'Muslims in Malaysia to celebrate Hari Raya on March 31',
#   'summary': 'kuala lumpur muslims in malaysia will celebrate hari raya aidilfitri on monday march  says the keeper of the rulers seal tan sri syed danial syed ahmad',
#   'summary_length': 151,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f10'),
#   'title': 'Negri Sembilan MB Aminuddin to defend PKR vice-presidency post',
#   'summary': 'seremban negri sembilan mentri besar datuk seri aminuddin harun is prepared to defend his prk vicepresidents post at the party elections scheduled in may',
#   'summary_length': 153,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f5a'),
#   'title': 'Perak Health Dept to fully enforce ban on display of tobacco products from April 1',
#   'summary': 'ipoh the perak health department will begin full enforcement of the smoking products control for public health act  which is set to take effect on april  ',
#   'summary_length': 154,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f1e'),
#   'title': '3.14 million vehicles expected to enter Pahang this Hari Raya, says exco rep',
#   'summary': 'kuantan a total of  million vehicles are expected to enter pahang from march  to april  for the hari raya aidilfitri celebrations says datuk razali kassim',
#   'summary_length': 154,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eec'),
#   'title': '14-year-old secondary school student dies after collapsing at school',
#   'summary': 'melaka the police have classified the case as a sudden death report pending the results of the postmortem examination to determine the exact cause of death',
#   'summary_length': 155,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed8'),
#   'title': 'Hari Raya exodus: Traffic crawls on Jalan Gua Musang-Kuala Lipis stretch due to rising number of vehicles',
#   'summary': 'kota baru traffic on several major federal roads in the gua musang district remained congested due to the rising number of vehicles as of pm saturday march ',
#   'summary_length': 156,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f15'),
#   'title': 'Fahmi retains Lembah Pantai PKR division chief post',
#   'summary': 'kuala lumpur pkr information chief datuk fahmi fadzil will retain uncontested the post of lembah pantai pkr division chief at the party elections next month',
#   'summary_length': 156,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f05'),
#   'title': 'Flight MH720 initiates emergency response after cargo fire alert',
#   'summary': 'putrajaya malaysia airlines confirmed that flight mh en route from jakarta to kuala lumpur initiated an emergency response following a cargo fire indication',
#   'summary_length': 156,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f5d'),
#   'title': 'Selangor cops nab seven linked to part-time job scam',
#   'summary': 'shah alam selangor police have arrested seven suspects including two women on suspicion of being involved in an online fraud syndicate offering parttime jobs',
#   'summary_length': 157,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ebc'),
#   'title': 'Malaysians report higher level of happiness than global average, Ipsos index shows',
#   'summary': 'kuala lumpur the ipsos happiness index  finds that malaysians report higher levels of happiness than the global average and several developed asian countries',
#   'summary_length': 157,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb4'),
#   'title': 'Ayer Kuning by-election: Perak DAP sets up special committee to support campaign',
#   'summary': 'kuala lumpur perak dap has set up a special action committee to support the campaign of the unity government candidate in the upcoming ayer kuning byelection',
#   'summary_length': 157,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017efe'),
#   'title': 'Man believed high on drugs almost falls from 10th floor of Sentul flat',
#   'summary': 'kuala lumpur a man believed to be under the influence of drugs almost fell to his death after hanging off the tenth floor of a flat in sentul on monday march ',
#   'summary_length': 158,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f42'),
#   'title': 'PERKESO disbursed RM5.82bil in benefits last year, says Sim',
#   'summary': 'kuala lumpur the social security organisation perkeso disbursed rmbil in benefits to  recipients last year said human resources minister steven sim chee keong',
#   'summary_length': 158,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eff'),
#   'title': 'Volunteer firefighters injured in Penang factory fire',
#   'summary': 'george town a pair of volunteer firefighters were injured during a firefighting operation involving two factories and a shop in jalan patani here sunday march ',
#   'summary_length': 159,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f30'),
#   'title': 'Malaysian Armed Forces in Sabah receive RM2.2bil allocation, Khaled says',
#   'summary': 'kota belud the malaysian armed forces in sabah have received an allocation of rmbil for various projects defence minister datuk seri mohamed khaled nordin says',
#   'summary_length': 159,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f09'),
#   'title': 'Number of Johor flood evacuees drops to 266',
#   'summary': 'johor baru the number of flood victims in johor has dropped to  people from  families who are currently housed at two temporary relief centres pps in batu pahat',
#   'summary_length': 160,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec3'),
#   'title': 'Toddler killed, six hurt in Melaka crash as mother nods off behind wheel',
#   'summary': 'melaka a twoyearold boy has been killed and six others injured in an accident involving two cars on jalan penghulu jaabar in bukit katil here on saturday march ',
#   'summary_length': 160,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f0e'),
#   'title': 'No flight cancellations by local airlines following Myanmar earthquake',
#   'summary': 'kuala lumpur malaysiabased airlines have confirmed that they did not cancel any flightsfollowing the powerful earthquake that hit central myanmar on friday march ',
#   'summary_length': 162,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f59'),
#   'title': "AirAsia suspending Ipoh-S'pore route: Perak wasn't informed in advance, says exco",
#   'summary': 'ipoh the perak state government was not consulted or informed prior to airasias announcement on the termination of the ipohsingapore route according to loh sze yee',
#   'summary_length': 163,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f5c'),
#   'title': 'Public Works Department allocated RM2mil to repair three sinkholes in Gua Musang',
#   'summary': 'gua musang the public works department pwd has allocated rmmil for the repair of three sinkholes in gua musang which will be opened to light vehicles before march ',
#   'summary_length': 163,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed7'),
#   'title': 'Hari Raya exodus: Traffic slow on KL-Karak Highway, LPT2, still smooth on NSE, LEKAS',
#   'summary': 'shah alam traffic flow on several major highways was reported to be slow due to an increase in the number of vehicles on saturday march  night sinar harian reports',
#   'summary_length': 163,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee3'),
#   'title': 'Hajiji blasts Warisan for politicising Sabah Governor’s birthday celebration',
#   'summary': 'kota kinabalu chief minister datuk seri hajiji noor has criticised parti warisan for politicising the official birthday celebrations of sabahs yang dipertua negeri',
#   'summary_length': 163,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec8'),
#   'title': 'Myanmar quake: Malaysia ready to aid Myanmar and Thailand, says PM Anwar',
#   'summary': 'petaling jaya malaysia is prepared to extend assistance and support humanitarian efforts following the powerful earthquake that struck myanmar and northern thailand',
#   'summary_length': 164,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f28'),
#   'title': 'Armizan rubbishes graft allegations tied to mineral prospecting licences',
#   'summary': 'kota kinabalu datuk armizan mohd ali has rubbished graft allegations made in an anonymous social media message linking him to a mineral prospecting licences scandal',
#   'summary_length': 164,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f12'),
#   'title': 'Bad weather expected in six states until 9pm tonight',
#   'summary': 'petaling jaya the malaysian meteorological department metmalaysia is warning of thunderstorms heavy rain and strong winds in several states until pm on saturday feb ',
#   'summary_length': 165,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee0'),
#   'title': 'Jakim lodges police report over insults against Islam',
#   'summary': 'kuala kangsar the malaysia islamic development department jakim has lodged a police report over insults against islam posted by irresponsible parties on social media',
#   'summary_length': 165,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ecc'),
#   'title': '27 new international flight routes to be introduced this year, says Tiong',
#   'summary': 'petaling jaya tourism arts and culture minister datuk seri tiong king sing has announced that a total of  new international flight routes will be introduced this year',
#   'summary_length': 166,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed0'),
#   'title': 'Woman pleads not guilty in case involving Mitra funds',
#   'summary': 'shah alam a woman has pleaded not guilty at the sessions court here to three charges of giving contradictory testimony to the malaysian anticorruption commission macc',
#   'summary_length': 166,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee1'),
#   'title': "Report religious figures involved in crimes, misconduct, says Mohd Na'im",
#   'summary': 'kuala terengganu the public is urged to report any religious figures or teachers involved in criminal activities or misconduct to enable appropriate action to be taken',
#   'summary_length': 167,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f29'),
#   'title': 'Journalist to face charges this Friday over alleged RM20,000 bribe',
#   'summary': 'petaling jaya malaysiakini reporter b nantha kumar is expected to be charged at the shah alam sessions court this friday march  over allegations of accepting a rm bribe',
#   'summary_length': 168,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f38'),
#   'title': 'Accident rate rises by 16% on first day of Ops Selamat',
#   'summary': 'ipoh a total of  road accidents were recorded on day one of ops selamat  on saturday marking a  increase compared to the  cases recorded on the first day of ops selamat ',
#   'summary_length': 169,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea9'),
#   'title': 'Jakoa to assess need for new bridge in Pos Belatim after collapse',
#   'summary': 'kota bharu the orang asli development department will assess the need for a new bridge in pos belatim gua musang after the existing structure collapsed due to heavy rain',
#   'summary_length': 169,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea3'),
#   'title': 'Investigation on man who allegedly slapped seven-year-old boy forwarded to DPP, say cops',
#   'summary': 'johor baru the police investigation into a case where a man allegedly slapped a sevenyearold boy has been completed and forwarded to the deputy public prosecutors office',
#   'summary_length': 169,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f25'),
#   'title': 'Mindef reassessing Black Hawk helicopter procurement approach',
#   'summary': 'alor gajah the defence ministry is currently reassessing the best procurement approach for uh black hawk helicopters for the army with a final decision expected this year',
#   'summary_length': 170,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef4'),
#   'title': "Malaysia ranked among world's Top 10 retirement destinations, Thailand only other South-East Asian country in list",
#   'summary': 'malaysia has been ranked as one of the top  countries for retirement in  by international living securing the seventh spot in the magazines annual global retirement index',
#   'summary_length': 170,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f4c'),
#   'title': 'Stability, peace come from mutual respect, says PM Anwar',
#   'summary': 'petaling jaya it is important to preserve unity and respect among all religious and racial groups in the country to ensure national stability datuk seri anwar ibrahim says',
#   'summary_length': 171,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f55'),
#   'title': "'Uncle Roger' shares his engagement photos on social media",
#   'summary': 'petaling jaya comedian and content creator nigel ng affectionately known to his nieces and nephews as uncle roger has shared some shots from a recent engagement photoshoot',
#   'summary_length': 171,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f4f'),
#   'title': 'Female uni student critically hurt after being stabbed by male friend on campus in Sungai Petani',
#   'summary': 'sungai petani a female student was critically injured after being stabbed by a male friend in an incident at a university campus here on monday march  sinar harian reports',
#   'summary_length': 171,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f47'),
#   'title': 'Flood relief efforts ongoing as 86 families remain in Beaufort centres',
#   'summary': 'kota kinabalu only  families remain in two relief centres in floodhit beaufort while displaced residents in keningau and sipitang were allowed to return home on sunday mar ',
#   'summary_length': 172,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f13'),
#   'title': 'Uphold unity, harmony, DPMs urge in Hari Raya messages',
#   'summary': 'kuala lumpur the people are encouraged to embrace the spirit of malaysia madani which emphasises love harmony and unity in celebrating hari raya aidilfitri on monday march ',
#   'summary_length': 172,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eca'),
#   'title': 'Businessman loses RM89,000 in survey equipment scam in Miri',
#   'summary': 'kuching a businessman in his s has lost more than rm after trying to procure survey instruments for what he believed was a government project only to discover it was a scam',
#   'summary_length': 172,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f08'),
#   'title': 'Anwar announces RM250 Aidilfitri aid for religious school teachers, imams and mosque personnel',
#   'summary': 'chukai prime minister datuk seri anwar ibrahim has announced a rm aidilfitri special financial aid for religious school teachers imams and mosque personnel across the country',
#   'summary_length': 174,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f19'),
#   'title': 'Father drowns while trying to rescue son from river in Klang',
#   'summary': 'shah alam a yearold man drowned while attempting to save his yearold son from a river in kampung bukit jati klang while they were fishing here late wednesday march  afternoon',
#   'summary_length': 174,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea7'),
#   'title': 'Health Ministry in final stages of discussion on private GP consultation fees',
#   'summary': 'sungai buloh the health ministry is in the final stages of discussions with the statistics department to determine the consultation fees for private general practitioners gps',
#   'summary_length': 174,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb7'),
#   'title': 'Man, 63, reported missing since Tuesday found dead',
#   'summary': 'ipoh an elderly man who was reported missing after going for physiotherapy treatment on tuesday march  was found dead in a room at the rpgc garden hotel here on thursday march ',
#   'summary_length': 176,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f22'),
#   'title': 'HR Minister urges media companies to take more active role in supporting part-time workers',
#   'summary': 'kuala lumpur media companies should take a more active role in supporting their parttime workers by contributing to the governments protection scheme says steven sim chee keong',
#   'summary_length': 176,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f32'),
#   'title': 'State governments must focus on key public issues, says Anwar',
#   'summary': 'nibong tebal prime minister datuk seri anwar ibrahim has called on all state governments to prioritise resolving public issues while also focusing on infrastructure development',
#   'summary_length': 176,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f0f'),
#   'title': "Debate PM term limits with decorum, credibility, says Finance Minister's aide",
#   'summary': 'kuala lumpur discussions on limiting the prime ministers tenure to a maximum of  years should be conducted with the utmost decorum and credibility says muhammad kamil abdul munim',
#   'summary_length': 178,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb9'),
#   'title': 'Govt aims to generate RM9bil from sale of treated rubberwood',
#   'summary': 'arau the government aims to generate rmbil from the sale of treated rubberwood through the replanting programme under the rubber industry smallholders development authority risda',
#   'summary_length': 178,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eba'),
#   'title': "Father thanks Malaysians for donating RM1.5mil for daughter's heart surgery",
#   'summary': 'kuala lumpur the father of eightyearold s harsheetaa sai has expressed his gratitude to malaysians for raising rmmil for his daughters upcoming heart surgery in the united states',
#   'summary_length': 178,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f1c'),
#   'title': 'Subang burglary suspect undergoes surgery to remove bullet fragment',
#   'summary': 'kuala lumpur one of the two suspects arrested for a house burglary on jalan ss subang jaya on friday march  has undergone surgery to remove a bullet fragment from his lower abdomen',
#   'summary_length': 180,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f35'),
#   'title': "Sovereign fund Danantara Indonesia names 'dream team' of former presidents, Sachs, Dalio and ex-Thai PM Thaksin",
#   'summary': 'new sovereign fund danantara indonesia unveiled on monday what it called a dream team to chart its strategy including expresidents as well as advisory roles for top finance experts',
#   'summary_length': 180,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec0'),
#   'title': 'Over 70,000 cattle smuggled across Malaysia-Thailand border in 2024',
#   'summary': 'kota bharu over  heads of cattle were smuggled across the malaysiathailand border states throughout the past year said agriculture and food security minister datuk seri mohamad sabu',
#   'summary_length': 181,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e98'),
#   'title': 'Cops probing video, organisation suspected of promoting communist ideology, says IGP',
#   'summary': 'kuala lumpur police are investigating a viral video clip depicting an unregistered organisation allegedly promoting communist ideologies in the country says tan sri razarudin husain',
#   'summary_length': 181,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed9'),
#   'title': 'JPJ flags non-roadworthy buses in safety crackdown ahead of Hari Raya',
#   'summary': 'seremban eleven of the more than  express buses inspected by the road transport department jpj in a sevenday operation have been slapped with nonroadworthy notices says anthony loke',
#   'summary_length': 181,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f4e'),
#   'title': 'New DAP leadership calls for unity to chart party future',
#   'summary': 'petaling jaya with daps central executive committee cec seeing a significant shift in roles its new members have given their commitment to unite under the new younger party leadership',
#   'summary_length': 183,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec5'),
#   'title': 'SMART, Nadma SAR teams arrive on air force aircraft in quake-hit Myanmar',
#   'summary': 'kuala lumpur the special malaysian disaster assistance and rescue team smart has arrived in myanmar on two air force am aircraft to contribute to the myanmar earthquake rescue efforts',
#   'summary_length': 183,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eeb'),
#   'title': 'Environment Dept investigating crude palm oil spill in Kota Tinggi',
#   'summary': 'johor baru authorities are investigating an oil spill at a factory in kota tinggi believed to have been caused by malfunctioning equipment said the the johor environment department doe',
#   'summary_length': 184,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eab'),
#   'title': 'Jakim summons author, urges removal of post insulting Prophet Muhammad',
#   'summary': 'kuala lumpur the islamic development department of malaysia jakim summoned the owner of the facebook account ainon mohd on monday march  over a post allegedly insulting prophet muhammad',
#   'summary_length': 185,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed5'),
#   'title': "Sabah Umno hits out at GRS over supposed 'governance issues'",
#   'summary': 'kota kinabalu sabah umno has criticised gabungan rakyat sabah grs for failing to uphold good governance citing a rmbil lawsuit against chief minister datuk seri hajiji noor as an example',
#   'summary_length': 186,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f36'),
#   'title': 'Video of robbers breaking into a home before they were shot dead is real, says cops',
#   'summary': 'kuala lumpur a video depicting four robbers entering a house in desa vita sepang before three of them were shot dead early friday morning march  has gained viral attention on social media',
#   'summary_length': 187,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea8'),
#   'title': 'Public urged not to obstruct garbage trucks during Hari Raya season',
#   'summary': 'melaka solid waste company  swm environment is appealing for the cooperation of revellers not to obstruct garbage trucks while visiting friends and family during hari rayas festive season',
#   'summary_length': 187,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef9'),
#   'title': 'Ops Birth: Detained legal practitioner assisted syndicate in registering birth',
#   'summary': 'kuala lumpur the legal practitioner arrested over corruption related to birth registration is suspected of processing birth certificate applications after receiving payment from applicants',
#   'summary_length': 188,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb5'),
#   'title': 'Customs foils drug smuggling attempts worth RM1.86mil at KLIA in two months',
#   'summary': 'sepang the customs department central zone iii at kuala lumpur international airport klia foiled seven drug smuggling attempts worth an estimated rmmil in the first two months of this year',
#   'summary_length': 188,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee4'),
#   'title': 'Speaker of Dewan Rakyat attends iftar event hosted by Cambodian PM in Phnom Penh',
#   'summary': 'speaker of the dewan rakyat tan sri johari abdul attended an iftar event with the local muslim community in phnom penh on monday march  hosted by cambodian prime minister samdech hun manet',
#   'summary_length': 188,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed4'),
#   'title': 'Anwar gives Tengku Zafrul nod to take on BAM role',
#   'summary': 'petaling jaya tengku datuk seri zafrul tengku abdul aziz says he has received the green light from prime minister datuk seri anwar ibrahim to lead the badminton association of malaysia bam',
#   'summary_length': 188,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee8'),
#   'title': 'State govt heads urge Muslims to celebrate Aidilfitri in unity and harmony',
#   'summary': 'kuala lumpur heads of state governments wished all muslims throughout the country a happy hari raya aidilfitri and invited the people to maintain and strengthen unity friendship and harmony',
#   'summary_length': 189,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e97'),
#   'title': 'Sufficient supply of local white rice in supermarkets, says Mohamad Sabu',
#   'summary': 'kota baru the agriculture and food security ministry has introduced measures to ensure an adequate supply of local white rice in supermarkets nationwide says minister datuk seri mohamad sabu',
#   'summary_length': 190,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f00'),
#   'title': 'Non-muslims embrace fasting, experience benefits',
#   'summary': 'kuala lumpur the desire to experience the benefits of fasting and show respect to their malay friends during ramadan has encouraged many nonmuslims to refrain from eating and drinking all day',
#   'summary_length': 191,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f01'),
#   'title': 'The act of ‘Salam’ becomes more meaningful this Raya with Maybank.',
#   'summary': 'salam exchanging greetings during hari raya aidilfitri is more than just a cherished tradition  its a gesture of love respect and unity  bringing hearts closer in moments of joy and reflection',
#   'summary_length': 192,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ee6'),
#   'title': 'Multi-storey school initiative to be introduced to address overcrowding, says Anwar',
#   'summary': 'kuala lumpur to address overcrowding in urban schools prime minister datuk seri anwar ibrahim said a multistorey school initiative will be introduced in collaboration with the corporate sector',
#   'summary_length': 192,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed2'),
#   'title': 'Allow parties involved to resolve temple relocation harmoniously, says Fahmi',
#   'summary': 'kuala lumpur communications minister datuk fahmi fadzil has reminded all parties not to exploit the issue of the relocation of a temple on jalan masjid india here for personal or political gain',
#   'summary_length': 193,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef3'),
#   'title': 'Govt allocates RM1.5bil to accelerate MSME digitalisation nationwide',
#   'summary': 'kuala lumpur the government has announced a rmbil fund to accelerate the digitalisation of micro small and medium enterprises msmes nationwide with the goal of boosting business competitiveness',
#   'summary_length': 193,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9d'),
#   'title': 'Two films blocked from screening for not paying production crew',
#   'summary': 'kuala lumpur two films that received incentives from the creative content fund dkk have been blocked from screening due to producers failure to pay production crew wages says datuk fahmi fadzil',
#   'summary_length': 193,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e96'),
#   'title': "China backs Malaysia's Asean leadership",
#   'summary': 'jakarta china has pledged strong support for malaysias asean  chairmanship emphasising the aseanchina free trade area acfta  protocol signing as a key priority for regional economic integration',
#   'summary_length': 193,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ec2'),
#   'title': 'Johor authorities identify 800 potholes in need of repair after floods',
#   'summary': 'johor baru some  potholes have been identified in johor following the recent floods says state works transportation infrastructure and communication committee chairman mohamad fazli mohamad salleh',
#   'summary_length': 196,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f06'),
#   'title': "Kelantan gov't to impose RM2,000 fine for irresponsible bulk waste disposal",
#   'summary': 'kota bharu the kelantan government will impose a fine of rm on individuals who dispose of bulk waste irresponsibly particularly during the preparations for the aidilfitri celebration in early april',
#   'summary_length': 197,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e99'),
#   'title': 'Family heading home for Raya injured in Tawau crash',
#   'summary': 'kota kinabalu a familys journey home to celebrate hari raya in tawau turned tragic when their car collided with an oncoming fourwheel drive leaving the mother and a young daughter seriously injured',
#   'summary_length': 197,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f39'),
#   'title': "Two company owners, clerk nabbed over bribes to expedite M'sian citizenship applications",
#   'summary': 'putrajaya two company owners and a clerk have been detained by the malaysian anticorruption commission macc on suspicion of being involved in a syndicate that bribed government department officials',
#   'summary_length': 197,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017edc'),
#   'title': 'Hari Raya exodus: Bangi resident spends 13 hours on the road returning to Terengganu',
#   'summary': 'kuala terengganu travellers returning to terengganu for the hari raya aidilfitri celebrations have shared their experiences of traffic congestion encountered during their journeys with sinar harian',
#   'summary_length': 197,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f2d'),
#   'title': 'Language, script are pillars of national identity, says Pahang Sultan',
#   'summary': 'kuala lipis sultan of pahang alsultan abdullah riayatuddin almustafa billah shah said language and script are reflections of heritage serving as the foundation of civilisation that must be preserved',
#   'summary_length': 198,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f2e'),
#   'title': 'Tengku Zafrul still an Umno member despite expressing intention to leave, says Zahid',
#   'summary': 'kuala lumpur umno president datuk seri dr ahmad zahid hamidi confirms that party supreme council member tengku datuk seri zafrul tengku abdul aziz expressed his intention to leave the party last week',
#   'summary_length': 199,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea0'),
#   'title': 'Police identify 12 accident-prone, 61 congested locations in KL',
#   'summary': 'kuala lumpur police have identified  accidentprone stretches and  areas with high traffic flow here in conjunction with hari raya aidilfitri through ops lancar which began on march  and ends on april ',
#   'summary_length': 200,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f16'),
#   'title': "Harmony in Malaysia's music industry is much needed and a must, says Karyawan and 3P Muzik",
#   'summary': 'karyawan and p muzik strongly believe that the new music guidelines are necessary as they protect the interests of the creators of the works that are being used namely the composers and the performers',
#   'summary_length': 200,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eef'),
#   'title': 'Kampung Sungai Baru residents obtain temporary stay of eviction of flat',
#   'summary': 'petaling jaya three residents of kampung sungai baru kampung baru have successfully obtained a temporary stay of the eviction order for their flat which was supposed to be enforced on wednesday march ',
#   'summary_length': 200,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ece'),
#   'title': 'Missing autistic boy found dead in river 500m from Kupang home',
#   'summary': 'baling a sombre atmosphere enveloped the home of the family of mohamad fayyad affan mohd fakhri a yearold child with autism after his body was discovered on the afternoon of march  sinar harian reports',
#   'summary_length': 201,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f53'),
#   'title': 'MACC chief extends Raya greetings, urges public to reject misconduct',
#   'summary': 'kuala lumpur malaysian anticorruption commission macc chief commissioner tan sri azam baki and the entire macc team extended hari raya aidilfitri greetings to all muslims in malaysia on saturday march ',
#   'summary_length': 201,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017efa'),
#   'title': 'Woman killed, two injured after car plunges into ravine at Bukit Ah Kim',
#   'summary': 'kota bharu an elderly woman was killed while two other people were injured after the car they were in skidded and plunged into a ravine at km jalan kota bharu  gua musang bukit ah kim on saturday march ',
#   'summary_length': 202,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f20'),
#   'title': 'Police to probe viral allegations of misconduct',
#   'summary': 'kuala lumpur the police will conduct an internal investigation into allegations of misconduct by police personnel while conducting a roadblock at the mines junction at sunday noon march  that went viral',
#   'summary_length': 202,
# ...
#   'summary': 'bagan serai planning for the raw water distribution project from sungai perak to bukit merah dam partly to support the kerian integrated green industrial park project and to supply treated water to penang is now in the final stages',
#   'summary_length': 231,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017edb'),
#   'title': 'Beaufort district still affected by flooding, 449 people housed in shelters',
#   'summary': 'kota kinabalu only the beaufort district remains affected by the flood disaster in sabah with  people from  families taking shelter in temporary relief centres pps as of pm on thursday march  compared to  people from  families at pm',
#   'summary_length': 232,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eea'),
#   'title': "Anwar saves Auntie Woon's Permatang Pauh ancestral home a second time",
#   'summary': 'bukit mertajam a woman caring for her two brothers one bedridden and the other a disabled person was filled with gratitude as prime minister datuk seri anwar ibrahim turned his attention to her dilapidated home in permatang pauh town',
#   'summary_length': 233,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ecf'),
#   'title': 'Perak Govt allocates RM245,000 to enhance welfare centres for orphans and schools',
#   'summary': 'tapah the perak state government in collaboration with the malaysia cooperative societies commission skm has allocated rm to upgrade the infrastructure of eight welfare centres across the state including orphanages and tahfiz schools',
#   'summary_length': 233,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f4d'),
#   'title': 'Married couple, company director remanded in RM8.4mil false claims probe',
#   'summary': 'kuala lumpur the malaysian anticorruption commission macc remanded a married couple and a company director suspected of submitting claims containing false details related to the misappropriation of approximately rmmil in company funds',
#   'summary_length': 234,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f2c'),
#   'title': 'Minister urges action against Facebook user for insulting Prophet Muhammad',
#   'summary': 'kuala lumpur the police and the malaysian communications and multimedia commission mcmc have been urged to investigate and take action against a facebook user for allegedly making remarks that insulted prophet muhammad on the platform',
#   'summary_length': 234,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f56'),
#   'title': "Ismail Sabri's corruption case an individual matter, nothing to do with Umno, says Ahmad Zahid",
#   'summary': 'kuala lumpur there will be no issue that umno will be affected following the investigation into the corruption case being faced by former prime minister datuk seri ismail sabri yaakob says its president datuk seri dr ahmad zahid hamidi',
#   'summary_length': 235,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eb0'),
#   'title': 'Riuh Raya Kita 2025 festival expected to generate over RM1.3mil in sales',
#   'summary': 'kuala lumpur the riuh raya kita  festival which showcases local products and designs under one roof in conjunction with hari raya aidilfitri at plaza raintree tun razak exchange trx here is expected to generate over rmmil in total sales',
#   'summary_length': 236,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017efd'),
#   'title': 'From tragedy to triumph: How SMART became a global search and rescue force',
#   'summary': 'kuala lumpur for nearly three decades the special malaysia disaster assistance and rescue team smart has been at the forefront of search and rescue sar operations and humanitarian aid efforts not only within the country but also globally',
#   'summary_length': 237,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea1'),
#   'title': "IGP flags youngsters' lavish lifestyles with no clear source of income",
#   'summary': 'kota baru young individuals who are neither influencers nor entrepreneurs have been found living lavish lifestyles owning luxury vehicles such as mustangs and bmws despite having no apparent source of income says tan sri razarudin husain',
#   'summary_length': 237,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ebb'),
#   'title': "Singapore's upgraded ferry terminal to boost travel to Malaysia and Indonesia",
#   'summary': 'singapores newly upgraded tanah merah ferry terminal tmft is poised to support future growth in travel to malaysias state of johor and indonesias riau islands with new facilities to enhance travellers experience according to its operator',
#   'summary_length': 237,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f0a'),
#   'title': 'Federal Court Judge Harmindar Singh chairs 25-member committee reviewing outdated criminal laws',
#   'summary': 'kuala lumpur in line with the madani governments aspiration to enhance and modernise malaysias criminal justice system the committee for the review and reform of the penal code criminal procedure code and evidence act has been established',
#   'summary_length': 238,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ea5'),
#   'title': 'Selangor Sultan graces opening of Kampung Klang Gate Baru Mosque',
#   'summary': 'kuala lumpur sultan of selangor sultan sharafuddin idris shah officiated the opening of the kampung klang gate baru mosque and broke fast with around  residents of gombak in conjunction with the monarchs ihya ramadan event with the people',
#   'summary_length': 238,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f41'),
#   'title': 'Sultan Nazrin breaks fast with media practitioners, NGOs, corporate bodies and youths',
#   'summary': 'kuala kangsar the sultan of perak sultan nazrin shah broke fast with media representatives nongovernmental organisations corporate sectors the private sector governmentlinked companies and youth at istana iskandariah here on saturday march ',
#   'summary_length': 240,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f21'),
#   'title': "'Jalur Gemilang' badges compulsory on school uniforms from April 21, says Education Ministry",
#   'summary': 'petaling jaya in an effort to inculcate love and pride for the country as well as promote unity discipline and responsibility students in institutions under the education ministry must wear a national flag badge on their uniforms from april ',
#   'summary_length': 241,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef6'),
#   'title': 'Appeals court: Councils responsible for maintaining trees on federal routes, MBS to pay damages to injured biker',
#   'summary': 'putrajaya the court of appeal here on wednesday march  ruled that the seremban city council mbs must pay rm in damages to a motorcyclist who suffered injuries following a fallen tree incident on a federal road in seremban  sinar harian reports',
#   'summary_length': 243,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f50'),
#   'title': "Anwar the best 'salesman' for Malaysian products internationally, says Felda chairman",
#   'summary': 'kuala lumpur federal land development authority felda chairman datuk seri ahmad shabery cheek describes prime minister datuk seri anwar ibrahim as malaysias best salesperson to promote the countrys products internationally thus increasing demand',
#   'summary_length': 245,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f3a'),
#   'title': 'MACC continues probe into Ismail Sabri, new files opened, says Azam Baki',
#   'summary': 'shah alam the malaysian anticorruption commission macc is continuing its investigation into former prime minister datuk seri ismail sabri yaakob with several new files opened based on the latest information and intelligence says tan sri azam baki',
#   'summary_length': 246,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eaf'),
#   'title': 'Selamat Hari Raya: Loke sends off passengers on Batik Air flight to Tawau, extends festive wishes',
#   'summary': 'petaling jaya as preparations for hari raya festivities intensify this weekend transport minister anthony loke visited kl international airport klia on saturday march  night to bid farewell to passengers of a batik air flight heading to tawau sabah',
#   'summary_length': 248,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ecb'),
#   'title': 'Selangor Ruler graces iftar event at UPM',
#   'summary': 'serdang the sultan of selangor sultan sharafuddin idris shah graced an iftar event and performed maghrib isyak and tarawih prayers at masjid upm with about  of its staff and students as well as residents in the surrounding areas on wednesday march ',
#   'summary_length': 248,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f03'),
#   'title': 'Malaysia pushes for stronger Asean-India cooperation under its 2025 chairmanship',
#   'summary': 'as the asean chair for  malaysia has called for strengthened aseanindia collaboration in key areas including cybersecurity digital governance trade and sustainable development in line with its chairmanship priorities of inclusivity and sustainability',
#   'summary_length': 250,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f3c'),
#   'title': 'Anwar urges Works Ministry to adopt latest, cost-effective technologies',
#   'summary': 'kuala lumpur prime minister datuk seri anwar ibrahim has urged the works ministry to continue adopting the latest costeffective technologies in the planning provision and development of projects to ensure they are executed more efficiently and promptly',
#   'summary_length': 252,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed6'),
#   'title': 'Selangor Sultan receives RM2.33mil in business tithe contributions',
#   'summary': 'klang the sultan of selangor sultan sharafuddin idris shah graced a ceremony at masjid bandar bukit raja on monday march  to receive business tithe contributions totalling rmmil from two companies  bank islam malaysia bhd rmmil and bawal eksklusif rmmil',
#   'summary_length': 253,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9f'),
#   'title': "MDH's investment in Sapura to repay local vendors, says PNB",
#   'summary': 'kuala lumpur the rmbil investment by malaysia development holding sdn bhd mdh in sapura energy bhd seb will be exclusively used to repay local vendors without benefitting any existing seb shareholders or financial creditors says permodalan nasional bhd pnb',
#   'summary_length': 256,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ede'),
#   'title': 'Malaysian Bar affirms commitment to judicial independence with unanimous resolutions',
#   'summary': 'kuala lumpur the malaysian bar unanimously passed two amended resolutions reaffirming its commitment to upholding judicial independence rule of law and separation of powers and condemning any interference by the executive legislature or unauthorised individuals',
#   'summary_length': 261,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017eda'),
#   'title': "'Torpedo' found on east coast beach raises concern, says UMT oceanographer",
#   'summary': 'kuala terengganu an oceanography expert from universiti malaysia terengganu umt said the recent discovery of a torpedoshaped metallic object on seberang takir beach kuala nerus has raised a little concern regarding the possibility of the projectile and its function',
#   'summary_length': 265,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f57'),
#   'title': 'Ismail Sabri probe: MACC detains money changer, later released due to health issues',
#   'summary': 'kuala lumpur the malaysian anti corruption commission macc on wednesday march  detained a money changer in connection with a corruption and money laundering case involving datuk seri ismail sabri yaakob before releasing him after he was found to have a heart problem',
#   'summary_length': 266,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f1b'),
#   'title': 'Report on fatal Titiwangsa LRT accident sent to Transport Ministry, Apad, says Prasarana',
#   'summary': 'kuala lumpur the report on the fatal incident involving a visually impaired man who was run over by a train after falling onto the titiwangsa light rail transit lrt tracks on feb  has been submitted to the transport ministry and the land public transport agency apad',
#   'summary_length': 266,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f1d'),
#   'title': 'Court grants Rosmah leave to include govt, police as third parties in missing jewellery suit',
#   'summary': 'putrajaya the court of appeal has granted leave to datin seri rosmah mansor to include the malaysian government and police as third parties in the usmil lawsuit filed against her by lebanese jeweller global royalty trading sal over more than  missing pieces of jewellery',
#   'summary_length': 270,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f40'),
#   'title': 'High demand for Hari Raya: KTMB adds four more ETS trains',
#   'summary': 'kuala lumpur keretapi tanah melayu bhd ktmb will provide four additional electric train service ets trains for the klsentralbutterworth and klsentralpadang besar routes including return journeys to meet travel needs in conjunction with the hari raya aidilfitri celebration',
#   'summary_length': 272,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f54'),
#   'title': 'Kolej Vokasional murder case: Accused swung cable charger at victim',
#   'summary': 'tawau the fourth accused in the murder case of kolej vokasional lahad datu student mohamad nazmie aizzat mohd narul azwan also known as ijat testified before the high court on friday that he had swung a phone charger cable in the victims direction while in dormitory  resak',
#   'summary_length': 273,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017e9b'),
#   'title': 'Raya rush: Traffic continues to build, vehicle numbers expected to rise on major highways',
#   'summary': 'kuala lumpur traffic flow on several major expresswayshas been reported to continue to be moving slowly on friday march  night due to a rise in the number of vehicles heading out of the city centre as city dwellers return to their hometowns to celebrate hari raya aidilfitri',
#   'summary_length': 274,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ed1'),
#   'title': "Govt's RM1.1bil investment injection into Sapura Energy a 'beacon of hope', say vendors",
#   'summary': 'kuala lumpur the governments rmbil investment in sapura energy bhd seb is a crucial lifeline for vendors grappling with severe cash flow challenges due to outstanding payments amounting to approximately more than rmmil offering a muchneeded boost to the local oil and gas ecosystem',
#   'summary_length': 281,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017ef7'),
#   'title': "Former Sabah minister Peter Anthony seeks to review Court of Appeal's decision",
#   'summary': 'kuala lumpur former sabah infrastructure development minister datuk peter anthony has filed a review of the court of appeals decision to uphold his threeyear jail sentence and rm fine for falsifying documents related to the maintenance and service contract at universiti malaysia sabah ums  years ago',
#   'summary_length': 300,
#   'has_keywords': False},
#  {'_id': ObjectId('67f7ebceb2d3f5bfad017f45'),
#   'title': 'Kolej Vokasional murder case: Second accused admits to kicking and stepping on victim',
#   'summary': 'tawau the second accused in the murder trial of kolej vokasional lahad datu student mohamad nazmie aizzat mohd narul azwan also known as ijat admitted in the high court on wednesday march  that he slapped the victims face struck his shoulder kicked him and stepped on his waist at the  belian dormitory room',
#   'summary_length': 307,
#   'has_keywords': False}]
